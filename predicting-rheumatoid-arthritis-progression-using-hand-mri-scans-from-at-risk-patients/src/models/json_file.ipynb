# %%
import os
import glob
import json
import pandas as pd  # For data manipulation and analysis
import pydicom  # For reading, modifying, and writing DICOM files
from pydicom.data import get_testdata_file  # For accessing test DICOM files
from pydicom.fileset import FileSet  # For working with DICOM FileSets
import numpy as np

# %%
# Reading the CSV file
training_data_dir = "/Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/" 
csv_path = os.path.join(training_data_dir, 'training_labels_subset.csv')
labels_df = pd.read_csv(csv_path)

# %%
import json
import os
import glob
import numpy as np
import pydicom
import time
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache
from tqdm import tqdm  # Add tqdm for progress tracking

class HandScanDataset3:
    def __init__(self, labels_df, data_dir):
        self.labels_df = labels_df
        self.data_dir = data_dir
        self.patient_ids = self.labels_df['patient ID'].astype(str).str.zfill(5).tolist()
        self.labels = self.labels_df['progression'].apply(lambda x: 1 if x == 'y' else 0).tolist()

    @lru_cache(maxsize=128)
    def get_best_patient_images(self, base_path):
        seq_len = 2
        selected_image_paths = []

        # Search for the 't1_vibe_we' directory recursively within the patient directory
        t1_vibe_we_path = None
        for root, dirs, files in os.walk(base_path):
            if 't1_vibe_we' in dirs:
                t1_vibe_we_path = os.path.join(root, 't1_vibe_we')
                break

        if not t1_vibe_we_path:
            print(f"Directory 't1_vibe_we' not found under {base_path}.")
            return selected_image_paths

        dicom_files = []
        for image_path in glob.glob(os.path.join(t1_vibe_we_path, '*')):
            try:
                dicom_file = pydicom.dcmread(image_path)
                dicom_files.append((dicom_file, image_path))
            except Exception as e:
                print(f"Error reading {image_path}: {e}")

        dicom_files.sort(key=lambda x: x[0].InstanceNumber)
        dicom_files = self.remove_duplicates(dicom_files)

        if dicom_files:
            max_sum = -1
            best_dicom_file, best_image_path = None, None
            for dicom_file, image_path in dicom_files:
                image = dicom_file.pixel_array
                image_sum = np.sum(image)
                if image_sum > max_sum:
                    max_sum = image_sum
                    best_dicom_file, best_image_path = dicom_file, image_path

            if best_dicom_file is not None:
                best_instance_number = best_dicom_file.InstanceNumber
                start_index = max(0, best_instance_number - (seq_len // 2))
                end_index = start_index + seq_len
                selected_slices = dicom_files[start_index:end_index]

                selected_image_paths = [image_path for _, image_path in selected_slices]

        return selected_image_paths

    def remove_duplicates(self, dicom_files):
        instance_dict = defaultdict(list)

        for dicom_file, image_path in dicom_files:
            instance_number = dicom_file.InstanceNumber
            instance_dict[instance_number].append((dicom_file, image_path))

        unique_dicom_files = []
        for instance_number, files in instance_dict.items():
            if len(files) > 1:
                best_slice = self.find_best_slice(files)
                unique_dicom_files.append(best_slice)
            else:
                unique_dicom_files.append(files[0])

        return unique_dicom_files

    def find_best_slice(self, dicom_files):
        for dicom_file, image_path in dicom_files:
            if hasattr(dicom_file, 'ContrastBolusAgent') and dicom_file.ContrastBolusAgent == 'DOTAREM':
                return dicom_file, image_path
        return dicom_files[0]

    def collect_image_paths(self):
        dataset_dict = {"training": []}

        start_time = time.time()  # Start timing

        with ThreadPoolExecutor() as executor:
            results = list(tqdm(executor.map(self._process_patient, zip(self.patient_ids, self.labels)), 
                                total=len(self.patient_ids), 
                                desc="Processing patients"))

        for result in results:
            dataset_dict["training"].extend(result)

        end_time = time.time()  # End timing
        print(f"Time taken: {end_time - start_time:.2f} seconds")

        return dataset_dict

    def _process_patient(self, patient_info):
        patient_id, label = patient_info
        patient_dir = os.path.join(self.data_dir, patient_id)
        image_paths = self.get_best_patient_images(patient_dir)

        if not image_paths:
            print(f"No image paths found for patient ID {patient_id} in {patient_dir}.")
        
        return [{"image": image_path, "label": label} for image_path in image_paths]

    def save_dataset_to_json(self, output_json_path):
        dataset_dict = self.collect_image_paths()
        with open(output_json_path, 'w') as f:
            json.dump(dataset_dict, f, indent=4)
        print(f"Dataset paths saved to {output_json_path}")

# Example usage:
# labels_df should be your dataframe with 'patient ID' and 'progression' columns.
dataset = HandScanDataset3(labels_df=labels_df, data_dir=training_data_dir)
dataset.save_dataset_to_json('training_data.json')
# Out:
# Processing patients:  14%|█▍        | 30/216 [1:28:18<18:17:31, 354.04s/it]
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613541035044351949.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_181/983862e0ae/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201309201112039112924598.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615001176086548823.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_245/3f1c6efdcb/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014100310134739398519057.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710393353946018296.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513455997608733246.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615293360857330584.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_228/cd13fc421d/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014072811423282379907692.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_239/31ed53b44e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014082715580167022913932.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_168/52bcced7f8/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013071015084174187948426.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201312231356166596031755.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014649711530277.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614452726608833116.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014329620830136.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_245/3f1c6efdcb/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014100309575158852303453.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_239/31ed53b44e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014082716125448359229369.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_181/983862e0ae/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013092011115541050124260.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_228/cd13fc421d/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.20140728120006984024177.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_168/52bcced7f8/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013071015085230020848888.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314015686586136149.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513312225329917824.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710361786975115211.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615325250772734024.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613593921196555692.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201406261359531518056291.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615181236056118295.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913585634938128231.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_181/983862e0ae/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201309201106198188820575.DCM: [Errno 60] Operation timed outError reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615022972497449406.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613541945574552354.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710361752425115203.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313593066291135340.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_245/3f1c6efdcb/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014100310133948988818656.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_239/31ed53b44e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014082716151126288029757.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513482892634033952.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_168/52bcced7f8/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013071014513157425132831.DCM: [Errno 60] Operation timed out
#
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_228/cd13fc421d/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014072811541366769519823.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710392836075018086.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615022513557349209.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613572179628255259.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513453795858732073.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201401171039243948317845.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613540997500451930.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614595725096548115.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513483344227234151.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613540714706551784.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710392120651517693.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614453769278433574.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613430210443540202.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513483130577734058.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615000321522148433.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415898666219009.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513482596046033825.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415464231918821.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425829094140071.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615000681534648629.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513483123584034052.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425494034639898.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710414863807418557.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614565825389145311.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513425498831930267.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415787412618959.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201406261357078010754455.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614565755113445279.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513482252008633677.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613570489692754335.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415990979119052.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615022181022749062.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513453878679732122.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613571356539954801.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710242810962102700.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614453171422733342.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513481984498933563.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710360442872414597.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425788591640050.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614565775018745288.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613594191486255806.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415019098618626.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513453615717231975.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615022180093549061.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013342195429706.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710391942757217595.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613595248871256268.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424176325329656.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614570422517345617.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613594374261055886.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710242613023602602.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014089165630030.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513460515076933443.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.20140117103934565818321.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613593756196855619.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513481914803533533.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913560696843426391.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425198444039748.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201401171041521716518704.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513455510676933010.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913590711262428822.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710361515611815128.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613594998699656157.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513460239943533339.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913592142940029526.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201312161500123329848837.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613594727487256040.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424734614229948.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710391713168517471.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614565715945945258.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913592057545429497.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513454689727032562.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613570890544854558.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710414885457718566.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014881382230379.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513311995405617706.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425426451939863.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710414583437018437.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444392818414176.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513482894317933953.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425016423139654.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201401171036157227415125.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513425527519830274.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913443452805813691.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613571265093654754.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614452381861532943.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513482035512833585.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415353577218773.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444477059514219.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513454585907532513.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710243586026003037.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615023375348649584.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613570480825254327.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913560067129826079.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424383089629766.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614452650858933078.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613424893767139590.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710360765230214767.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014384878030160.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424850179930007.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613570628711954414.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615000254223948402.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710392254383017763.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913443499540913719.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513460184314333321.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615023141496849482.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613571426998054842.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444358000414159.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201401171041516172818665.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513312667766518033.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613570510414154344.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615000526991048553.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710360561328914658.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913591592634529298.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513425115579630142.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710414783765318524.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614595685328048090.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425615920439963.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014784087330334.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424811835629988.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.20140626135704922254289.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615023169851049494.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710414610183618448.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444798358614319.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513455638588533080.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614453365329833444.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710391796853017516.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913592244697229571.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613570570398754382.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614570321735845568.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415829175818980.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613541760131352298.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444448777814204.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513482053343733590.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710391821122217529.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201406261359408621455728.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615022923628749386.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013929838329962.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513460346892533389.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613572684581155455.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710243058688002826.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615001330144748886.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444693697014285.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513455414921132960.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710393223064718248.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614595624305548058.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201406261359429152455814.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014356202230148.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513454375829532397.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425454028439878.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614453288002133404.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710414637084618461.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014340993130139.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424442320229797.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613430028242540147.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615022126776049038.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415650617018899.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013863746829932.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424262507929703.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613541972477652361.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614452774134633142.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201401171024358123803014.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013367903329714.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513425352781630223.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121615000056717448293.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613594128509855779.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014377088130157.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710415792331618965.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_180/ec642759d7/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013090513424630267529893.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_229/758a731c5e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014062613425355591139828.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614570696810545701.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710243068323302829.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014092596230031.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_207/a5f62446cc/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014011710391633861617426.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_181/983862e0ae/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201309201112074167324768.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_191/d85a6b7dc2/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013121614453210374133362.DCM: [Errno 89] Operation canceled
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913591934180429452.DCM: [Errno 89] Operation canceled
# ...
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615352123681634901.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615182487928618868.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201402191344388987013876.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913591576053129284.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615323668755533204.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201404161535074070834280.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913592324319229613.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913443817951813882.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615322929791432795.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615322914881832777.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615351013029334414.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444027396713990.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201402191344392223613924.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615293485965730649.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615350670721834265.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014396559430163.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201402191355587449425945.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615351329825234550.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615322861403132742.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913560451892226275.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615351989704634843.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615323641685533185.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913585681655428255.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013368437429715.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615324543341533673.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615323186297832943.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913560480911626290.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013956899029974.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201404161535193731934805.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615293698190030755.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013831578629919.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201404161529429907830975.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_214/b9de28053e/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014041615323157242632922.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014960688530408.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313591160267534328.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313593051624335335.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913560881169026445.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913443463316213700.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314015432894436038.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313444442042919685.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014250153530100.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013557206029800.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314015755712436179.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014268805230109.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314015115489435899.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313593621401335555.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013476569929764.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913560819431626427.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.201312231344442264019664.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314014988225135843.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913444397935714179.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014321736730132.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314015593857736109.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313562325266532117.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914014876517330376.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013953101929973.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313593448263035498.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313444362211619643.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913590763402828846.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913591645593529329.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313561763035431835.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313444288698519603.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913585945053628403.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913590768545228852.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313562140996832025.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313444699965219814.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021913555813021825948.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_212/afb1d5d511/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2014021914013920972229956.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122314014744309735738.DCM: [Errno 60] Operation timed out
# Error reading /Users/eleanorbolton/Library/CloudStorage/OneDrive-UniversityofLeeds/t1_vibe_we_hand_subset/CCP_202/4e8c00160f/t1_vibe_we/1.3.12.2.1107.5.2.36.40258.2013122313591096352034292.DCM: [Errno 60] Operation timed out
# Processing patients:  18%|█▊        | 38/216 [4:47:36<22:27:12, 454.11s/it]

# %%
    def get_best_patient_images(self, base_path):
        """ 
        Process all images in the 't1_vibe_we' subfolder of each subject.
        Sort images by Instance Number and return a sequence of a fixed length.
        """
        seq_len = 2
        all_images = []
        img_shape = (512, 384)  # Set a default image shape

        for root, dirs, files in os.walk(base_path):
            if 't1_vibe_we' in dirs:
                t1_vibe_we_path = os.path.join(root, 't1_vibe_we')
                
                # Get the images in the 't1_vibe_we' sequence
                dicom_files = []
                for image_path in glob.glob(os.path.join(t1_vibe_we_path, '*')):
                    try:
                        dicom_file = pydicom.dcmread(image_path)
                        dicom_files.append((dicom_file, image_path))
                    except Exception as e:
                        print(f"Error reading {image_path}: {e}")

                # Sort the files by Instance Number
                dicom_files.sort(key=lambda x: x[0].InstanceNumber)
                
                # Remove duplicates
                dicom_files = self.remove_duplicates(dicom_files)

                # Find the best slice
                if dicom_files:
                    # Find the slice with the highest intensity
                    max_sum = -1
                    best_dicom_file, best_image_path = None, None
                    for dicom_file, image_path in dicom_files:
                        image = dicom_file.pixel_array
                        image_sum = np.sum(image)
                        if image_sum > max_sum:
                            max_sum = image_sum
                            best_dicom_file, best_image_path = dicom_file, image_path

                    if best_dicom_file is not None:
                        best_instance_number = best_dicom_file.InstanceNumber

                        # Calculate the start and end indices for the selected sequence
                        start_index = max(0, best_instance_number - (seq_len // 2))
                        end_index = start_index + seq_len

                        # Select the slices around the best slice
                        selected_slices = dicom_files[start_index:end_index]

                        images = []
                        for dicom_file, image_path in selected_slices:
                            try:
                                image = self.process_dicom_image(image_path)
                                images.append(image)
                            except Exception as e:
                                print(f"Error processing image {image_path}: {e}")

                        # Determine the original image dimensions
                        if images:
                            img_shape = images[0].shape  # Set img_shape based on the first image

                        if len(images) < seq_len:
                            # Pad with zero images of the same shape as the original images
                            diff = seq_len - len(images)
                            images.extend([np.zeros(img_shape, dtype=np.uint8) for _ in range(diff)])

                        all_images.extend(images)

        return np.array(all_images)


    def remove_duplicates(self, dicom_files):
        """ Remove duplicate instance numbers, keeping only the slice with the highest sum of intensities. """
        instance_dict = defaultdict(list)

        for dicom_file, image_path in dicom_files:
            instance_number = dicom_file.InstanceNumber
            instance_dict[instance_number].append((dicom_file, image_path))

        # Compare DICOM files with the same Instance Number
        unique_dicom_files = []
        for instance_number, files in instance_dict.items():


            if len(files) > 1:

                # Optionally, still choose the best slice based on your criteria, but here we're just showing the differences
                best_slice = self.find_best_slice(files)
                unique_dicom_files.append(best_slice)

            else:
                unique_dicom_files.append(files[0])


        return unique_dicom_files


    def find_best_slice(self, dicom_files):
        """ Find the slice with the 'DOTAREM' ContrastBolusAgent or, as a fallback, return the first available slice. """
        best_slice = None

        # Check for the slice with 'DOTAREM'
        for dicom_file, image_path in dicom_files:
            if hasattr(dicom_file, 'ContrastBolusAgent') and dicom_file.ContrastBolusAgent == 'DOTAREM':
                best_slice = (dicom_file, image_path)
                break  # Stop searching once we find the 'DOTAREM' slice

        # Fallback: If no slice with 'DOTAREM' is found, return the first slice
        if best_slice is None:
            best_slice = dicom_files[0]

        return best_slice


    def process_dicom_image(self, path: str, resize=True) -> np.ndarray:
            dicom_file = pydicom.dcmread(path)
            image = dicom_file.pixel_array.astype(np.float32)
            
            # If the image has any zero-sized dimensions, return a placeholder or skip processing
            if 0 in image.shape:
                print(f"Skipping image due to invalid shape: {image.shape}")
                return np.zeros((512, 384), dtype=np.uint8) 
            
            # Normalize the image: Zero mean and unit variance
            mean = np.mean(image)
            std = np.std(image)
            image = (image - mean) / (std + 1e-7)  # Add a small epsilon to prevent division by zero

            # Apply 95% clipping
            lower_bound = np.percentile(image, 2.5)
            upper_bound = np.percentile(image, 97.5)
            image = np.clip(image, lower_bound, upper_bound)

            # Normalize again after clipping
            mean = np.mean(image)
            std = np.std(image)
            image = (image - mean) / (std + 1e-7)

            # Convert back to uint8 for further processing
            image = (image * 255).astype(np.uint8)

            if resize:
                image = Image.fromarray(image)
                image = image.resize((384, 512))  # Resize the image to 512x384
                image = np.array(image)

            return image


    def get_sequence_images(self, path: str) -> list:
            images = []
            
            # Get a list of all DICOM files in the directory
            image_path_list = glob.glob(os.path.join(path, '*'))
            
            # Read the DICOM files and store them with their instance numbers
            dicom_files = []
            for image_path in image_path_list:
                try:
                    dicom_file = pydicom.dcmread(image_path)
                    instance_number = dicom_file.InstanceNumber
                    dicom_files.append((instance_number, image_path))
                except Exception as e:
                    print(f"Error reading {image_path}: {e}")
            
            # Sort the files by instance number
            dicom_files.sort(key=lambda x: x[0])
            
            # Read the pixel data in sorted order
            for _, image_path in dicom_files:
                try:
                    dicom_file = pydicom.dcmread(image_path)
                    image = dicom_file.pixel_array
                    images.append(image)
                except Exception as e:
                    print(f"Error reading pixel data from {image_path}: {e}")
            
            return images

# %%
def collect_image_paths(labels_df, data_dir, seq_len=2):
    dataset_dict = {"training": [], "validation": []}

    for _, row in labels_df.iterrows():
        patient_id = str(row['patient ID']).zfill(5)  # Adjust column name if necessary
        label = 1 if row['progression'] == 'y' else 0  # Adjust column name if necessary

        patient_dir = os.path.join(data_dir, patient_id)
        t1_vibe_we_path = os.path.join(patient_dir, 't1_vibe_we')

        if os.path.exists(t1_vibe_we_path):
            dicom_files = []
            for image_path in glob.glob(os.path.join(t1_vibe_we_path, '*')):
                try:
                    dicom_file = pydicom.dcmread(image_path)
                    dicom_files.append((dicom_file, image_path))
                except Exception as e:
                    print(f"Error reading {image_path}: {e}")

            # Sort the files by Instance Number
            dicom_files.sort(key=lambda x: x[0].InstanceNumber)

            # Find the best slice and collect paths
            if dicom_files:
                max_sum = -1
                best_dicom_file, best_image_path = None, None
                for dicom_file, image_path in dicom_files:
                    image = dicom_file.pixel_array
                    image_sum = np.sum(image)
                    if image_sum > max_sum:
                        max_sum = image_sum
                        best_dicom_file, best_image_path = dicom_file, image_path

                if best_dicom_file is not None:
                    best_instance_number = best_dicom_file.InstanceNumber
                    start_index = max(0, best_instance_number - (seq_len // 2))
                    end_index = start_index + seq_len
                    selected_slices = dicom_files[start_index:end_index]

                    for dicom_file, image_path in selected_slices:
                        entry = {
                            "image": image_path,
                            "label": label
                        }
                        dataset_dict["training"].append(entry)

    return dataset_dict

# %%
def save_dataset_to_json(dataset_dict, output_json_path):
    with open(output_json_path, 'w') as f:
        json.dump(dataset_dict, f, indent=4)

# Example usage:
dataset_dict = collect_image_paths(labels_df=training_data_dir, data_dir=training_data_dir)
output_json_path = 'training_data.json'
save_dataset_to_json(dataset_dict, output_json_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>         json.dump(dataset_dict, f, indent=4)
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> # Example usage:
# ----> <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> dataset_dict = collect_image_paths(labels_df=training_data_dir, data_dir=training_data_dir)
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> output_json_path = 'training_data.json'
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> save_dataset_to_json(dataset_dict, output_json_path)
#
# /Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> def collect_image_paths(labels_df, data_dir, seq_len=2):
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     dataset_dict = {"training": [], "validation": []}
# ----> <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     for _, row in labels_df.iterrows():
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>         patient_id = str(row['patient ID']).zfill(5)  # Adjust column name if necessary
#       <a href='vscode-notebook-cell:/Users/eleanorbolton/Documents/project_repo/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/Predicting-Rheumatoid-Arthritis-Progression-Using-Hand-MRI-Scans-from-At-Risk-Patients/predicting-rheumatoid-arthritis-progression-using-hand-mri-scans-from-at-risk-patients/src/models/json_file.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>         label = 1 if row['progression'] == 'y' else 0  # Adjust column name if necessary
#
# AttributeError: 'str' object has no attribute 'iterrows'
